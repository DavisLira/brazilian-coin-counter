# %%
import matplotlib.pyplot as plt
from skimage.io import imread

image_path = '../images/20220827_130449.jpg' 

try:
    img = imread(image_path)
    plt.imshow(img)
    plt.title("Imagem Carregada com Sucesso")
    plt.axis('off')
    plt.show()
except FileNotFoundError:
    print(f"Erro: Não foi encontrada a imagem em {image_path}. Verifique o caminho!")
